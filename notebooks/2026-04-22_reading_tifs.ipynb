# %%
import glob
import pathlib as pl
import tifffile as tiff
import src.loader as io
import glob

# %%
tiffpath = pl.Path("/Volumes/AhmedLab/princess/data/raw/pIP10_TSeries_20260421_GC8m_fly02_win02_trial0-001.")

# %%
exp_id = 'GC8m-101'

raw_path = io.get_base_path(exp_id,'raw')
# processed_path = io.get_base_path(exp_id, 'processed')
print(raw_path)
# Out:
# /Volumes/AhmedLab/princess/data/raw/pIP10_TSeries_20260421_GC8m-101

# %%
for idx, file in enumerate(glob.glob(f'{raw_path}/*.tif')):
    if idx == 0:
        img_array = tiff.imread(file)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/6j/4hb4hfhs6ygdhcvnvsxhm5yr0000gs/T/ipykernel_1406/1443608227.py in ?()
#       1 for idx, file in enumerate(glob.glob(f'{raw_path}/*.tif')):
#       2     if idx == 0:
# ----> 3         img_array = tiff.imread(file)
#
# /opt/homebrew/anaconda3/envs/maui2/lib/python3.13/site-packages/tifffile/tifffile.py in ?(files, selection, aszarr, key, series, level, squeeze, maxworkers, buffersize, mode, name, offset, size, pattern, axesorder, categories, imread, imreadargs, sort, container, chunkshape, chunkdtype, axestiled, ioworkers, chunkmode, fillvalue, zattrs, multiscales, omexml, superres, out, out_inplace, _multifile, _useframes, **kwargs)
#    1257
#    1258                     from .zarr import zarr_selection
#    1259
#    1260                     return zarr_selection(store, selection, out=out)
# ...

# %%
# does imread already implements lazy loading??
imgarray = tiff.imread(tfile)
